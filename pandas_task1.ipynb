# %% [markdown]
# ###### 1:Create a new data frame where loss is recorded.

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("C:\\Users\\Swami\\Downloads\\datasets\\datasets\\Superstore.xls")

# %%
df
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### 2 find the index of the data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# #### 3 find the columns of the data

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 4 if columns name is having space then remove the
# space and rename the column. find the various ways to rename the column

# %%
a=df.columns.str.replace(' ', '')
a
# Out:
# Index(['no', 'order_id', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'Sub-Category', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 5 display first 40 records

# %%
df.head(40)
# Out:
#       no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %%
### Q 6 display last 15 records from the data.
df.tail(15)
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %%
## 7. change the setting to display minimum 30 rows for given data
pd.options.display.min_rows=30

# %%
df
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11      12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12      13.0  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...

# %%
## 8. change the display setting to minimum row as 3
pd.options.display.min_rows=3

# %%
df
# Out:
#           no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0        NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...      ...             ...        ...        ...           ...         ...
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States    Henderson  ...       42420
# ...            ...       ...            ...          ...  ...         ...
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 0      South  FUR-BO-10001798        Furniture    Bookcases
# ...      ...              ...              ...          ...
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# ...

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
## 9.take a slice from the dataframe based on the columns city, state, region, profit columns
df.loc[:,['City', 'State','Region','Profit']]
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %%
## 10 Take a slice based on data available at 1000 to 1500 position and columns from 4 to 8
df.iloc[1000:1501,4:9]
# Out:
#            Ship Mode Customer ID  Customer Name      Segment        Country
# 1000  Standard Class    FM-14290   Frank Merwin  Home Office  United States
# ...              ...         ...            ...          ...            ...
# 1500  Standard Class    NG-18430  Nathan Gelder     Consumer  United States
#
# [501 rows x 5 columns]

# %%
## 11. Rename the index starts from 1900 to end of the data
df.index=range(1900,1900+len(df),1)

# %%
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Postal Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales  Quantity  \
# ...

# %%
## 12. Take a slice from data based on index having name as 1920 , 1940, 1945, 1980, and columns asprofit, state, category, sub-category, region
df.loc[[1920,1940,1945,1980],['Profit','State','Category','Sub-Category','Region']]   #profit, state, category, sub-category, region
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %%
## 13. Check the data type of columns
df.dtypes
# Out:
# no                      float64
# order _id                object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.set_index
# Out:
# <bound method DataFrame.set_index of            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Postal Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
# ...

# %%
## 14. Find out the record for the month of jun-2014
 df[(df['Ship Date']>='2014-06-01')& (df['Ship Date']<='2014-06-30')]
# Out:
#   Cell In[22], line 2
#     df[(df['Ship Date']>='2014-06-01')& (df['Ship Date']<='2014-06-30')]
#     ^
# IndentationError: unexpected indent

# %%
#### 15 Calculate month wise average of profit.
df['Order Date']=pd.to_datetime(df['Order Date'])
df['m']=df['Order Date'].dt.month
df['m']
# Out:
# 1900     11
#          ..
# 11893     5
# Name: m, Length: 9994, dtype: int32

# %%
df.groupby(df['m'])['Profit'].mean()
# Out:
# m
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %%
#df['Profit'].head()

# %%
### Question 16. Create the new data frame for California
# pd.find("California")
df['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df[df['State']=="California"]
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#          Customer Name    Segment        Country         City  ... Region  \
# 1902   Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
# ...                ...        ...            ...          ...  ...    ...
# 11893     Chris Cortes   Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1902   OFF-LA-10000240  Office Supplies       Labels
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# ...

# %%
### Question 17. Find sum of sales
df['Sales'].sum()
# Out:
# np.float64(2297200.8603000003)

# %%
## 18. Find state wise sum of sales.
df.groupby("State")["Sales"].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
### Question 19. Find month wise sum of sales
df['Order Date']=pd.to_datetime(df['Order Date'])
df['m']=df['Order Date'].dt.month
df['m']

# %%
df.groupby(df['m'])['Sales'].sum()

# %%
df.set_index('Ship Date', inplace = True)

# %%
#one more way for question 
df.resample(rule='M').mean(['Profit','Sales'])
# Out:
# C:\Users\Swami\AppData\Local\Temp\ipykernel_17504\3824728732.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample(rule='M').mean(['Profit','Sales'])
#                      no   Postal Code       Sales  Quantity  Discount  \
# Ship Date
# 2014-01-31  4382.791667  53708.375000  184.376819  3.736111  0.131250
# 2014-02-28  5647.220000  65736.640000  108.130560  3.260000  0.161000
# 2014-03-31  5512.843972  51768.035461  359.633681  3.737589  0.164184
# 2014-04-30  5358.000000  60717.888889  225.099741  4.022222  0.127407
# 2014-05-31  4744.333333  51771.158730  178.403810  3.714286  0.148016
# 2014-06-30  4097.189394  52517.969697  272.664058  3.833333  0.162273
# 2014-07-31  4899.264901  59980.450331  218.480755  3.735099  0.183113
# 2014-08-31  4866.040268  58306.583893  202.988201  4.167785  0.125503
# 2014-09-30  4941.391129  54284.758065  294.865538  3.681452  0.163790
# ...

# %%
### Question 20: Find country wise and city wise average profit
df.groupby(['Country','City'])['Profit'].mean()
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %%
### QUESTION 21 Calculate region wise average profit.
df.groupby(df['Region'])['Profit'].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %%
## Question 21 Calculate region wise average profit.
df.groupby('Region')["Profit"].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %%
### Question 22 Find the ship mode which is more profitable.
ship_mode = df.groupby('Ship Mode')['Profit'].sum().idxmax()
#m_profit= ship_mode.max()
#m_profit
ship_mode
# Out:
# 'Standard Class'

# %%
### Question 23 Create a new data frame where loss is recorded

df[df['Profit']<0]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       Customer ID     Customer Name      Segment        Country  \
# 1903     SO-20335    Sean O'Donnell     Consumer  United States
# ...           ...               ...          ...            ...
# 11862    CM-12655  Corinna Mitchell  Home Office  United States
#
#                   City  ... Postal Code   Region       Product ID   Category  \
# 1903   Fort Lauderdale  ...       33311    South  FUR-TA-10000577  Furniture
# ...                ...  ...         ...      ...              ...        ...
# 11862          Houston  ...       77041  Central  FUR-BO-10004218  Furniture
#
#       Sub-Category                                       Product Name  \
# ...

# %%
### Question 24 Find category wise sub category wise sales
df.groupby(['Category','Sub-Category'])['Sales']
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %%
### Question 25 Create a data frame for record where discount is 0
df.columns
df[df['Discount']==0]
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %%
## 26. Create a data frame where order date and ship date both are in JAN-2014 
cod1=(df['Ship Date']>= '2014-01-01') &(df['Ship Date']<='2014-01-31')
cod2=(df["Order Date"]>='2014-01-01') &(df["Order Date"]<='2014-01-31')

# %%
df[cod1|cod2]
# Out:
#            no       order _id Order Date  Ship Date       Ship Mode  \
# 2492    593.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# ...       ...             ...        ...        ...             ...
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
#
#       Customer ID     Customer Name   Segment        Country    City  ...  \
# 2492     MS-17830     Melanie Seite  Consumer  United States  Laredo  ...
# ...           ...               ...       ...            ...     ...  ...
# 11889    TB-21400  Tom Boeckenhauer  Consumer  United States   Miami  ...
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 2492        78041  Central  OFF-AR-10004078  Office Supplies          Art
# ...           ...      ...              ...              ...          ...
# 11889       33180    South  FUR-FU-10001889        Furniture  Furnishings
#
#                  Product Name   Sales  Quantity  Discount  Profit
# ...

# %%
## 27 Find records having profit for consumer segment.
df.columns
df.groupby('Segment')['Profit']
df
# Out:
#            no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer Name   Segment        Country         City  ... Region  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...  South
# ...             ...       ...            ...          ...  ...    ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...   West
#
#             Product ID         Category Sub-Category  \
# 1900   FUR-BO-10001798        Furniture    Bookcases
# ...                ...              ...          ...
# 11893  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product Name   Sales Quantity  \
# 1900                   Bush Somerset Collection Bookcase  261.96        2
# ...

# %%
## 28 Generate new data frame for every state (hint: dynamic variable creation) 
un_state=df["State"].unique()

# %%
s_df={state:df[df["State"]==state] for state in un_state}
s_df
# Out:
# {'Kentucky':                 no       order _id Order Date     Ship Mode Customer ID  \
#  Ship Date
#  2016-11-11     NaN             NaN 2016-11-08  Second Class    CG-12520
#  ...            ...             ...        ...           ...         ...
#  2017-09-18  9961.0  CA-2017-141446 2017-09-16  Second Class    CL-12700
#
#             Customer Name      Segment        Country       City     State  \
#  Ship Date
#  2016-11-11   Claire Gute     Consumer  United States  Henderson  Kentucky
#  ...                  ...          ...            ...        ...       ...
#  2017-09-18  Craig Leslie  Home Office  United States   Florence  Kentucky
#
#              Postal Code Region       Product ID    Category Sub-Category  \
#  Ship Date
#  2016-11-11        42420  South  FUR-BO-10001798   Furniture    Bookcases
#  ...                 ...    ...              ...         ...          ...
#  2017-09-18        41042  South  TEC-AC-10002305  Technology  Accessories
#
# ...

# %%
## 29 Generate the region wise, state wise average profit and sales and then extract information for east region. 
cod=df.groupby(['Region','State'])[['Profit','Sales']].mean()
#od2=df.groupby(['Region','State'])['Sales'].mean()
#cod[cod['Region'] == "East"]

# %%
a = cod.reset_index()

# %%
a[a["Region"]=="East"]
# Out:
#    Region                 State      Profit       Sales
# 13   East           Connecticut   42.823071  163.223866
# 14   East              Delaware  103.930988  285.948635
# 15   East  District of Columbia  105.958930  286.502000
# 16   East                 Maine   56.810775  158.816250
# 17   East              Maryland   66.963608  225.766886
# 18   East         Massachusetts   50.262975  212.106919
# 19   East         New Hampshire   63.203807  270.093481
# 20   East            New Jersey   75.176260  275.110092
# 21   East              New York   65.637011  275.599531
# 22   East                  Ohio  -36.186304  166.861697
# 23   East          Pennsylvania  -26.507598  198.487077
# 24   East          Rhode Island  130.100523  404.070643
# 25   East               Vermont  204.088936  811.760909
# 26   East         West Virginia   46.480400  302.456000

# %%
cod[cod['Region'] == "East"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 cod[cod['Region'] == "East"]
#
# NameError: name 'cod' is not defined

# %%
## 30  Find all record for furniture delivered in Texas .
# df.nunique
df[(df['State']=='Texas') & (df['Category']=="Furniture")]
# Out:
#            no       order _id Order Date  Ship Date    Ship Mode Customer ID  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10  First Class    GH-14485
# ...       ...             ...        ...        ...          ...         ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22  First Class    CM-12655
#
#           Customer Name      Segment        Country        City  ...  \
# 1936          Gene Hale    Corporate  United States  Richardson  ...
# ...                 ...          ...            ...         ...  ...
# 11862  Corinna Mitchell  Home Office  United States     Houston  ...
#
#       Postal Code   Region       Product ID   Category Sub-Category  \
# 1936        75080  Central  FUR-FU-10003664  Furniture  Furnishings
# ...           ...      ...              ...        ...          ...
# 11862       77041  Central  FUR-BO-10004218  Furniture    Bookcases
#
#                                             Product Name     Sales  Quantity  \
# ...
